# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = \
keras.datasets.fashion_mnist.load_data()

# %%
from sklearn.model_selection import train_test_split

train_scaled = train_input / 255
# 차원은 -값을 무시해도 된다
train_scaled = train_scaled.reshape(-1, 28 * 28)

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42)

# %%
#(개수, 활성화함수(activation), 모양(input_shape/ 28*28로 설정함))
# 은닉층 (출력층보다 노드(?)개수 많아야함)
dense1 = keras.layers.Dense(100, activation='sigmoid', input_shape=(784,))
# 출력층 (input_shape은 은닉층에서 이미 설정됨)
dense2 = keras.layers.Dense(10, activation='softmax')

model = keras.Sequential([dense1, dense2])  # 심층신경망 : 출력층은 마지막

# %%
model.summary()
# 층(?)하나마다 +1 되므로 파라미터 개수 +n개되어있음
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               78500
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 설정
model.compile(loss='sparse_categorical_crossentropy',  # 원핫인코딩되어있음
              metrics=['accuracy'])

# 모델 학습
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.5608 - accuracy: 0.8079
# Epoch 2/5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.4064 - accuracy: 0.8537
# Epoch 3/5
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.3718 - accuracy: 0.8647
# Epoch 4/5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.3483 - accuracy: 0.8735
# Epoch 5/5
# 48000/48000 [==============================] - 3s 52us/sample - loss: 0.3312 - accuracy: 0.8799

# %% [markdown]
# 시그모이드 단점
# - 어떤 숫자든 0~1사이로 변환 시 값의 손실
# - 대신 렐루 함수를 사용하기도 함 (이미지처리에 주로 사용)

# %%
(train_input, train_target), (test_input, test_target) = \
keras.datasets.fashion_mnist.load_data()

train_scaled = train_input / 255

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42)

# %%
model = keras.Sequential()
# input_shape은 입력층 바로 다음에만!
# flatten - 알아서 1차원으로 바꿔줌 = 유틸리티 층
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 설정
model.compile(loss='sparse_categorical_crossentropy',  # 원핫인코딩되어있음
              metrics=['accuracy'])

# 모델 학습
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.5304 - accuracy: 0.8137
# Epoch 2/5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.3950 - accuracy: 0.8575
# Epoch 3/5
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.3573 - accuracy: 0.8705
# Epoch 4/5
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.3356 - accuracy: 0.8810
# Epoch 5/5
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.3219 - accuracy: 0.8854

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.373276192565759, 0.87441665]

# %%
(train_input, train_target), (test_input, test_target) = \
keras.datasets.fashion_mnist.load_data()

train_scaled = train_input / 255

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42)

# %%
model = keras.Sequential()
# input_shape은 입력층 바로 다음에만!
# flatten - 알아서 1차원으로 바꿔줌 = 유틸리티 층
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
# 모델 설정
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 모델 학습
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Train on 48000 samples
# Epoch 1/5
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.5266 - accuracy: 0.8169
# Epoch 2/5
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.3956 - accuracy: 0.8579
# Epoch 3/5
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.3518 - accuracy: 0.8722
# Epoch 4/5
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.3287 - accuracy: 0.8786
# Epoch 5/5
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.3090 - accuracy: 0.8856

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 12000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.339680600742499, 0.8821667]
