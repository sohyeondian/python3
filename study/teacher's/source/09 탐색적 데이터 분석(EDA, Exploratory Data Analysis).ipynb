# %% [markdown]
# ## 표준 라이브러리 로딩

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### 데이터셋 로딩
# - Raw Data : 정재가 되지 않은 데이터 세트
# - 토이 데이터 : 분석에 용이한 형태로 만들어진 연습용 데이터 세트

# %%
chipo = pd.read_csv('D:/DataScience/data/chipotle.tsv', sep='\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### step1. 기본 정보 탐색

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
chipo.shape
# Out:
# (4622, 5)

# %% [markdown]
# #### chipo 데이터셋의 피처 분석
# - order_id : 주문번호
# - quantity : 주문수량
# - item_name : 메뉴명
# - choice_description : 토핑(소스 + 토핑)
# - item_price : 메뉴가격

# %% [markdown]
# ### 분석 주제나 목적
# 1. 가장 많이 판매된 메뉴 Top 10은 무엇일까?
# 2. 음식 메뉴는 총 몇가지 일까?
# 3. 메뉴별 판매량은 얼마나 될까?
# 4. 메뉴별 가격대는 얼마일까?
# 5. 메뉴중 제일 비싼 메뉴는 무엇일까?
# 6. 어떤 음식 조합이 제일 선호될까?

# %%
# 수치형 데이터의 기초 통계량을 분석하는 함수
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# ### 피처(Feature, Column, Attribute)
# 1. 수치형 피처 : 연속형(실수형), 비연속형(정수형)
# 2. 범주형 피처 : 순서가 있는 범주형, 순서가 없는 범주형(명목형)

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
chipo.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
# order_id를 범주형 데이터로 변형
# astype, is~
chipo['order_id'] = chipo['order_id'].astype(str)
chipo.describe()
# Out:
#           quantity
# count  4622.000000
# mean      1.075725
# std       0.410186
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      15.000000

# %%
# 범주형 데이터의 개수 확인, unique() = drop + sort
# order_id, item_name
# 개수 : len()
print(len(chipo['order_id'].unique()))
print(len(chipo['item_name'].unique()))
# Out:
# 1834
# 50

# %%
chipo['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
#        'Burrito', 'Crispy Tacos', 'Carnitas Crispy Tacos', 'Steak Salad',
#        'Chips and Mild Fresh Tomato Salsa', 'Veggie Soft Tacos',
#        'Carnitas Salad Bowl', 'Barbacoa Salad Bowl', 'Salad',
#        'Veggie Crispy Tacos', 'Veggie Salad', 'Carnitas Salad'],
#       dtype=object)

# %%
# value_counts() : 개별 요소의 건수를 계산하여 반환
len(chipo['item_name'].value_counts())
# Out:
# 50

# %% [markdown]
# ### step2. 인사이트(Insight) 발견 : 탐색과 시각화

# %% [markdown]
# #### 가장 많이 판매된 메뉴 Top 10

# %%
# value_counts() 함수는 오로지 Series 객체에만 적용된다.
chipo['item_name'].value_counts()[:10]
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Steak Bowl             211
# Chips                  211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: item_name, dtype: int64

# %%
item_count = chipo['item_name'].value_counts()[:10]
# enumerate(array, start=number)
for idx, (val, cnt) in enumerate(item_count.iteritems(), 1):
    print("Top ", idx, " : ", val, cnt)
# Out:
# Top  1  :  Chicken Bowl 726
# Top  2  :  Chicken Burrito 553
# Top  3  :  Chips and Guacamole 479
# Top  4  :  Steak Burrito 368
# Top  5  :  Canned Soft Drink 301
# Top  6  :  Steak Bowl 211
# Top  7  :  Chips 211
# Top  8  :  Bottled Water 162
# Top  9  :  Chicken Soft Tacos 115
# Top  10  :  Chicken Salad Bowl 110

# %% [markdown]
# ### 메뉴별 주문 개수와 총량

# %%
# item_name별 주문(order_id) 개수
# groupby() : DataFrame.groupby('기준컬럼명')
order_count = chipo.groupby('item_name')['order_id'].count()
order_count[:10]
# Out:
# item_name
# 6 Pack Soft Drink         54
# Barbacoa Bowl             66
# Barbacoa Burrito          91
# Barbacoa Crispy Tacos     11
# Barbacoa Salad Bowl       10
# Barbacoa Soft Tacos       25
# Bottled Water            162
# Bowl                       2
# Burrito                    6
# Canned Soda              104
# Name: order_id, dtype: int64

# %%
# item별 주문 총량 : 주문수량의 합계
order_quantity = chipo.groupby('item_name')['quantity'].sum()
order_quantity[:10]
# Out:
# item_name
# 6 Pack Soft Drink         55
# Barbacoa Bowl             66
# Barbacoa Burrito          91
# Barbacoa Crispy Tacos     12
# Barbacoa Salad Bowl       10
# Barbacoa Soft Tacos       25
# Bottled Water            211
# Bowl                       4
# Burrito                    6
# Canned Soda              126
# Name: quantity, dtype: int64

# %%
# os별로 한글처리하는 작업
import platform
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name =font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown system.....")

# %%
# 주문총량
item_name_list = order_quantity.index.tolist()
x_pos = np.arange(len(item_name_list))
y_pos = order_quantity.values.tolist()

plt.bar(x_pos, y_pos)
plt.title('전체 메뉴별 주문 총량')
plt.xlabel('메뉴인덱스')
plt.ylabel('주문수량')
plt.show()

# %% [markdown]
# ### step3. 데이터 전처리 & 데이터 통계분석

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null object
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(1), object(4)
# memory usage: 180.6+ KB

# %%
chipo['item_price'].head()
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %% [markdown]
# #### item_price 자료형을 수치형으로 변환하는 작업

# %%
def funct(x):
    return float(x[1:])

# %%
# strip() : 좌우 공백을 제거하는 문자열 관련 함수
chipo['item_price'] = chipo['item_price'].str.lstrip('$')
chipo['item_price'].astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#         ...
# 4592    11.75
# 4593    11.75
# 4594    11.75
# 4595     8.75
# 4596     4.45
# 4597     1.25
# 4598     1.50
# 4599     8.75
# 4600     4.45
# 4601     1.25
# 4602     9.25
# 4603     9.25
# 4604     8.75
# 4605     4.45
# 4606     1.25
# 4607    11.75
# 4608    11.25
# 4609     1.25
# 4610    11.75
# 4611    11.25
# 4612     9.25
# 4613     2.15
# 4614     1.50
# 4615     8.75
# 4616     4.45
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chipo.head()
# Out:
#   order_id  quantity                              item_name  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# 익명의 함수 lambda 입력 : 출력
# apply(함수) : 반복적으로 수행하는 작업
chipo['item_price'] = chipo['item_price'].apply(lambda x : float(x[1:]))
chipo.describe()
# Out:
#           quantity   item_price
# count  4622.000000  4622.000000
# mean      1.075725     7.464336
# std       0.410186     4.245557
# min       1.000000     1.090000
# 25%       1.000000     3.390000
# 50%       1.000000     8.750000
# 75%       1.000000     9.250000
# max      15.000000    44.250000

# %%
chipo.head(10)
# Out:
#   order_id  quantity                              item_name  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
# 5        3         1                           Chicken Bowl
# 6        3         1                          Side of Chips
# 7        4         1                          Steak Burrito
# 8        4         1                       Steak Soft Tacos
# 9        5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 6                                                NaN        1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...        9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25

# %%
# 메뉴별 평균 금액 => 제일 비싼 메뉴와 평균가격을 파악할 수 있다.
chipo_cost = chipo.groupby('item_name')['item_price'].mean()
chipo_cost.sort_values(ascending=False)
# Out:
# item_name
# Bowl                                     14.800000
# Steak Salad Bowl                         11.847931
# Chicken Salad Bowl                       11.170455
# Carnitas Crispy Tacos                    11.137143
# Carnitas Salad Bowl                      11.056667
# Barbacoa Crispy Tacos                    10.928182
# Carnitas Bowl                            10.833971
# Steak Bowl                               10.711801
# Barbacoa Salad Bowl                      10.640000
# Veggie Soft Tacos                        10.565714
# Steak Burrito                            10.465842
# Veggie Bowl                              10.211647
# Steak Crispy Tacos                       10.209714
# Barbacoa Bowl                            10.187273
# Veggie Salad Bowl                        10.138889
# Carnitas Burrito                         10.132712
# Chicken Bowl                             10.113953
# Chicken Burrito                          10.082857
# Chicken Crispy Tacos                     10.045319
# Barbacoa Soft Tacos                      10.018400
# Veggie Burrito                            9.839684
# Barbacoa Burrito                          9.832418
# Steak Soft Tacos                          9.746364
# Chicken Soft Tacos                        9.635565
# Carnitas Soft Tacos                       9.398500
# Chicken Salad                             9.010000
# Carnitas Salad                            8.990000
# Steak Salad                               8.915000
# Veggie Crispy Tacos                       8.490000
# Veggie Salad                              8.490000
# Salad                                     7.400000
# Crispy Tacos                              7.400000
# Burrito                                   7.400000
# 6 Pack Soft Drink                         6.610185
# Chips and Guacamole                       4.595073
# Nantucket Nectar                          3.641111
# Izze                                      3.390000
# Chips and Fresh Tomato Salsa              3.285091
# Chips and Tomatillo Green Chili Salsa     3.087209
# Chips and Roasted Chili Corn Salsa        3.084091
# Chips and Tomatillo Red Chili Salsa       3.072917
# Chips and Mild Fresh Tomato Salsa         3.000000
# Chips and Tomatillo-Red Chili Salsa       2.987500
# Chips and Tomatillo-Green Chili Salsa     2.544194
# Chips and Roasted Chili-Corn Salsa        2.390000
# Chips                                     2.342844
# Bottled Water                             1.867654
# Side of Chips                             1.840594
# Canned Soft Drink                         1.457641
# Canned Soda                               1.320577
# Name: item_price, dtype: float64

# %% [markdown]
# ### 가장 많이 선호하는 메뉴는 무엇인가?

# %%
chipo.head(10)
# Out:
#   order_id  quantity                              item_name  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
# 5        3         1                           Chicken Bowl
# 6        3         1                          Side of Chips
# 7        4         1                          Steak Burrito
# 8        4         1                       Steak Soft Tacos
# 9        5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 6                                                NaN        1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...        9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25

# %%
# 메뉴순위체크 - 메뉴주문수량 순위체크
# 주로 많이 먹는 메뉴명
# 메뉴별 인기있는 선택옵션

#chipo = chipo.drop(['order_id','item_price'], axis=1, inplace=True)
chipo
# Out:
#       quantity                              item_name  \
# 0            1           Chips and Fresh Tomato Salsa
# 1            1                                   Izze
# 2            1                       Nantucket Nectar
# 3            1  Chips and Tomatillo-Green Chili Salsa
# 4            2                           Chicken Bowl
# 5            1                           Chicken Bowl
# 6            1                          Side of Chips
# 7            1                          Steak Burrito
# 8            1                       Steak Soft Tacos
# 9            1                          Steak Burrito
# 10           1                    Chips and Guacamole
# 11           1                   Chicken Crispy Tacos
# 12           1                     Chicken Soft Tacos
# 13           1                           Chicken Bowl
# 14           1                    Chips and Guacamole
# 15           1  Chips and Tomatillo-Green Chili Salsa
# 16           1                        Chicken Burrito
# 17           1                        Chicken Burrito
# 18           2                            Canned Soda
# 19           1                           Chicken Bowl
# 20           1                    Chips and Guacamole
# 21           1                       Barbacoa Burrito
# 22           1                       Nantucket Nectar
# 23           1                        Chicken Burrito
# 24           1                                   Izze
# 25           1           Chips and Fresh Tomato Salsa
# 26           1                           Chicken Bowl
# 27           1                       Carnitas Burrito
# 28           1                            Canned Soda
# 29           1                        Chicken Burrito
# ...        ...                                    ...
# 4592         1                       Barbacoa Burrito
# 4593         1                          Carnitas Bowl
# 4594         1                          Barbacoa Bowl
# 4595         1                           Chicken Bowl
# 4596         1                    Chips and Guacamole
# 4597         1                      Canned Soft Drink
# 4598         1                          Bottled Water
# 4599         1                           Chicken Bowl
# 4600         1                    Chips and Guacamole
# 4601         1                      Canned Soft Drink
# 4602         1                       Barbacoa Burrito
# 4603         1                       Barbacoa Burrito
# 4604         1                           Chicken Bowl
# 4605         1                    Chips and Guacamole
# 4606         1                      Canned Soft Drink
# 4607         1                          Steak Burrito
# 4608         1                         Veggie Burrito
# 4609         1                      Canned Soft Drink
# 4610         1                          Steak Burrito
# 4611         1                         Veggie Burrito
# 4612         1                          Carnitas Bowl
# 4613         1                                  Chips
# 4614         1                          Bottled Water
# 4615         1                     Chicken Soft Tacos
# 4616         1                    Chips and Guacamole
# 4617         1                          Steak Burrito
# 4618         1                          Steak Burrito
# 4619         1                     Chicken Salad Bowl
# 4620         1                     Chicken Salad Bowl
# 4621         1                     Chicken Salad Bowl
#
#                                      choice_description
# 0                                                   NaN
# 1                                          [Clementine]
# 2                                               [Apple]
# 3                                                   NaN
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                   NaN
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 10                                                  NaN
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 14                                                  NaN
# 15                                                  NaN
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# 18                                             [Sprite]
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 20                                                  NaN
# 21    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...
# 22                                 [Pomegranate Cherry]
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# 24                                         [Grapefruit]
# 25                                                  NaN
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...
# 27    [[Tomatillo-Green Chili Salsa (Medium), Roaste...
# 28                                         [Dr. Pepper]
# 29    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# ...                                                 ...
# 4592  [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...
# 4593  [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...
# 4594  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# 4596                                                NaN
# 4597                                           [Nestea]
# 4598                                                NaN
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# 4600                                                NaN
# 4601                                        [Diet Coke]
# 4602                      [Tomatillo Green Chili Salsa]
# 4603                      [Tomatillo Green Chili Salsa]
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# 4605                                                NaN
# 4606                                             [Coke]
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 4608  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 4609                                           [Sprite]
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 4613                                                NaN
# 4614                                                NaN
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]
# 4616                                                NaN
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
#
# [4622 rows x 3 columns]

# %%
# choice_description 결측처리 : Origin
chipo['choice_description'].fillna('Origin', inplace=True)
chipo.head()
# Out:
#   order_id  quantity                              item_name  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                             Origin        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                             Origin        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ### choice_description 피처
# - [[소스], [토핑]] => [소스, [토핑]]
# - 두 개의 열로 쪼개는 작업 : saurce, topping

# %%
type(chipo['choice_description'])
# Out:
# pandas.core.series.Series

# %%
# 파이썬 정규표현식 모듈
import re

num = 0
for i in chipo['choice_description']:
    # 패턴[^a-zA-Z, ] : 알파벳과 ',' 그리고 공백을 제외하고 모두 지우겠다는 의미
    chipo['choice_description'][num] = re.sub(pattern='[^a-zA-Z, ]', repl='', string=i)
    num += 1
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
chipo.head(10)
# Out:
#   order_id  quantity                              item_name  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
# 5        3         1                           Chicken Bowl
# 6        3         1                          Side of Chips
# 7        4         1                          Steak Burrito
# 8        4         1                       Steak Soft Tacos
# 9        5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                             Origin        2.39
# 1                                         Clementine        3.39
# 2                                              Apple        3.39
# 3                                             Origin        2.39
# 4  TomatilloRed Chili Salsa Hot, Black Beans, Ric...       16.98
# 5  Fresh Tomato Salsa Mild, Rice, Cheese, Sour Cr...       10.98
# 6                                             Origin        1.69
# 7  Tomatillo Red Chili Salsa, Fajita Vegetables, ...       11.75
# 8  Tomatillo Green Chili Salsa, Pinto Beans, Chee...        9.25
# 9  Fresh Tomato Salsa, Rice, Black Beans, Pinto B...        9.25

# %% [markdown]
# 1. List => DataFrame
# 2. Series => DataFrame : Series객체.to_frame()
# 3. DataFrame 칼럼 추가/삭제

# %%
# 주문당 평균 계산금액을 추출하기
chipo.head(10)
# Out:
#   order_id  quantity                              item_name  \
# 0        1         1           Chips and Fresh Tomato Salsa
# 1        1         1                                   Izze
# 2        1         1                       Nantucket Nectar
# 3        1         1  Chips and Tomatillo-Green Chili Salsa
# 4        2         2                           Chicken Bowl
# 5        3         1                           Chicken Bowl
# 6        3         1                          Side of Chips
# 7        4         1                          Steak Burrito
# 8        4         1                       Steak Soft Tacos
# 9        5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                             Origin        2.39
# 1                                         Clementine        3.39
# 2                                              Apple        3.39
# 3                                             Origin        2.39
# 4  TomatilloRed Chili Salsa Hot, Black Beans, Ric...       16.98
# 5  Fresh Tomato Salsa Mild, Rice, Cheese, Sour Cr...       10.98
# 6                                             Origin        1.69
# 7  Tomatillo Red Chili Salsa, Fajita Vegetables, ...       11.75
# 8  Tomatillo Green Chili Salsa, Pinto Beans, Chee...        9.25
# 9  Fresh Tomato Salsa, Rice, Black Beans, Pinto B...        9.25

# %%
chipo.groupby('order_id')['item_price'].sum().mean()
# Out:
# 18.811428571428717

# %%
chipo.groupby('order_id')['item_price'].sum().describe()
# Out:
# count    1834.000000
# mean       18.811429
# std        11.652512
# min        10.080000
# 25%        12.572500
# 50%        16.200000
# 75%        21.960000
# max       205.250000
# Name: item_price, dtype: float64

# %%
# 한 주문에 10달러 이상 지출한 주문번호를 추출하시오.
# step1. 주문번호별 주문금액의 합계
chipo_orderid_group = chipo.groupby('order_id')['item_price'].sum()
# step2. 금액에서 10달러 이상인 자료만 추출
type(chipo_orderid_group)
# Out:
# pandas.core.series.Series

# %%
result = chipo_orderid_group[chipo_orderid_group >= 10]
result[:10]
# Out:
# order_id
# 1       11.56
# 10      13.20
# 100     10.08
# 1000    20.50
# 1001    10.08
# 1002    10.68
# 1003    13.00
# 1004    21.96
# 1005    12.15
# 1006    71.40
# Name: item_price, dtype: float64

# %% [markdown]
# ### 메뉴별 가격 구하기

# %%
# 수량이 1개인 제품만 골라낸다.
chipo_one_item = chipo[chipo.quantity == 1]
# 메뉴별 금액이 가장 작은 값
chipo_per_item = chipo_one_item.groupby('item_name').min()
chipo_per_item
# Out:
#                                       order_id  quantity  \
# item_name
# 6 Pack Soft Drink                         1076         1
# Barbacoa Bowl                             1000         1
# Barbacoa Burrito                          1002         1
# Barbacoa Crispy Tacos                      110         1
# Barbacoa Salad Bowl                       1283         1
# Barbacoa Soft Tacos                       1103         1
# Bottled Water                             1009         1
# Bowl                                       279         1
# Burrito                                    214         1
# Canned Soda                                100         1
# Canned Soft Drink                         1003         1
# Carnitas Bowl                             1007         1
# Carnitas Burrito                          1003         1
# Carnitas Crispy Tacos                     1774         1
# Carnitas Salad                            1500         1
# Carnitas Salad Bowl                       1035         1
# Carnitas Soft Tacos                       1011         1
# Chicken Bowl                                10         1
# Chicken Burrito                           1005         1
# Chicken Crispy Tacos                      1010         1
# Chicken Salad                              109         1
# Chicken Salad Bowl                        1015         1
# Chicken Soft Tacos                        1006         1
# Chips                                     1005         1
# Chips and Fresh Tomato Salsa                 1         1
# Chips and Guacamole                         10         1
# Chips and Mild Fresh Tomato Salsa          279         1
# Chips and Roasted Chili Corn Salsa         102         1
# Chips and Roasted Chili-Corn Salsa        1156         1
# Chips and Tomatillo Green Chili Salsa      102         1
# Chips and Tomatillo Red Chili Salsa       1020         1
# Chips and Tomatillo-Green Chili Salsa        1         1
# Chips and Tomatillo-Red Chili Salsa       1215         1
# Crispy Tacos                               217         1
# Izze                                         1         1
# Nantucket Nectar                             1         1
# Salad                                      575         1
# Side of Chips                             1002         1
# Steak Bowl                                1006         1
# Steak Burrito                              100         1
# Steak Crispy Tacos                        1044         1
# Steak Salad                               1406         1
# Steak Salad Bowl                          1032         1
# Steak Soft Tacos                          1054         1
# Veggie Bowl                               1006         1
# Veggie Burrito                            1033         1
# Veggie Crispy Tacos                        668         1
# Veggie Salad                              1094         1
# Veggie Salad Bowl                         1066         1
# Veggie Soft Tacos                         1132         1
#
#                                                                       choice_description  \
# item_name
# 6 Pack Soft Drink                                                                   Coke
# Barbacoa Bowl                              Fresh Tomato Mild, Lettuce, Black Beans, Rice
# Barbacoa Burrito                                               Black Beans, Rice, Cheese
# Barbacoa Crispy Tacos                  Fresh Tomato Salsa Mild, TomatilloGreen Chili ...
# Barbacoa Salad Bowl                    Fresh Tomato Salsa, Fajita Vegetables, Rice, B...
# Barbacoa Soft Tacos                    Fresh Tomato Salsa Mild, Roasted Chili Corn Sa...
# Bottled Water                                                                     Origin
# Bowl                                   AdoboMarinated and Grilled Steak, Sour Cream, ...
# Burrito                                AdoboMarinated and Grilled Chicken, Pinto Bean...
# Canned Soda                                                                    Coca Cola
# Canned Soft Drink                                                                   Coke
# Carnitas Bowl                          Fresh Tomato Mild, Guacamole, Lettuce, Rice, S...
# Carnitas Burrito                       Fresh Tomato Mild, Lettuce, Black Beans, Guaca...
# Carnitas Crispy Tacos                  Fresh Tomato Salsa, Fajita Vegetables, Rice, B...
# Carnitas Salad                         Fresh Tomato Salsa Mild, Roasted Chili Corn Sa...
# Carnitas Salad Bowl                    Fresh Tomato Salsa, Rice, Black Beans, Cheese,...
# Carnitas Soft Tacos                    Fresh Tomato Salsa Mild, Black Beans, Rice, Fa...
# Chicken Bowl                                          Fresh Tomato Mild, Guacamole, Rice
# Chicken Burrito                        Fresh Tomato Mild, Black Beans, Rice, Sour Cre...
# Chicken Crispy Tacos                             Fresh Tomato Salsa Mild, Fajita Veggies
# Chicken Salad                                       Fresh Tomato Salsa Mild, Black Beans
# Chicken Salad Bowl                                                    Fresh Tomato Salsa
# Chicken Soft Tacos                                                    Fresh Tomato Salsa
# Chips                                                                             Origin
# Chips and Fresh Tomato Salsa                                                      Origin
# Chips and Guacamole                                                               Origin
# Chips and Mild Fresh Tomato Salsa                                                 Origin
# Chips and Roasted Chili Corn Salsa                                                Origin
# Chips and Roasted Chili-Corn Salsa                                                Origin
# Chips and Tomatillo Green Chili Salsa                                             Origin
# Chips and Tomatillo Red Chili Salsa                                               Origin
# Chips and Tomatillo-Green Chili Salsa                                             Origin
# Chips and Tomatillo-Red Chili Salsa                                               Origin
# Crispy Tacos                                          AdoboMarinated and Grilled Chicken
# Izze                                                                          Blackberry
# Nantucket Nectar                                                                   Apple
# Salad                                  Brown Rice, AdoboMarinated and Grilled Chicken...
# Side of Chips                                                                     Origin
# Steak Bowl                             Fresh Tomato Mild, Guacamole, Lettuce, Pinto B...
# Steak Burrito                                                                 Brown Rice
# Steak Crispy Tacos                                    Fresh Tomato Mild, Lettuce, Cheese
# Steak Salad                            Fresh Tomato Salsa Mild, Rice, Cheese, Sour Cr...
# Steak Salad Bowl                       Fresh Tomato Salsa, Black Beans, Cheese, Guaca...
# Steak Soft Tacos                                                      Fresh Tomato Salsa
# Veggie Bowl                            Fresh Tomato Salsa Mild, Pinto Beans, Black Be...
# Veggie Burrito                         Fresh Tomato Salsa Mild, Black Beans, Fajita V...
# Veggie Crispy Tacos                    Fresh Tomato Salsa Mild, Pinto Beans, Rice, Ch...
# Veggie Salad                           Fresh Tomato Salsa Mild, Roasted Chili Corn Sa...
# Veggie Salad Bowl                      Fresh Tomato Salsa, Fajita Vegetables, Black B...
# Veggie Soft Tacos                      Fresh Tomato Salsa Mild, Pinto Beans, Rice, Ch...
#
#                                        item_price
# item_name
# 6 Pack Soft Drink                            6.49
# Barbacoa Bowl                                8.69
# Barbacoa Burrito                             8.69
# Barbacoa Crispy Tacos                        8.99
# Barbacoa Salad Bowl                          9.39
# Barbacoa Soft Tacos                          8.99
# Bottled Water                                1.09
# Bowl                                         7.40
# Burrito                                      7.40
# Canned Soda                                  1.09
# Canned Soft Drink                            1.25
# Carnitas Bowl                                8.99
# Carnitas Burrito                             8.69
# Carnitas Crispy Tacos                        8.99
# Carnitas Salad                               8.99
# Carnitas Salad Bowl                          9.39
# Carnitas Soft Tacos                          8.99
# Chicken Bowl                                 8.19
# Chicken Burrito                              8.19
# Chicken Crispy Tacos                         8.49
# Chicken Salad                                8.19
# Chicken Salad Bowl                           8.75
# Chicken Soft Tacos                           8.49
# Chips                                        1.99
# Chips and Fresh Tomato Salsa                 2.29
# Chips and Guacamole                          3.89
# Chips and Mild Fresh Tomato Salsa            3.00
# Chips and Roasted Chili Corn Salsa           2.95
# Chips and Roasted Chili-Corn Salsa           2.39
# Chips and Tomatillo Green Chili Salsa        2.95
# Chips and Tomatillo Red Chili Salsa          2.95
# Chips and Tomatillo-Green Chili Salsa        2.39
# Chips and Tomatillo-Red Chili Salsa          2.39
# Crispy Tacos                                 7.40
# Izze                                         3.39
# Nantucket Nectar                             3.39
# Salad                                        7.40
# Side of Chips                                1.69
# Steak Bowl                                   8.69
# Steak Burrito                                8.69
# Steak Crispy Tacos                           8.69
# Steak Salad                                  8.69
# Steak Salad Bowl                             9.39
# Steak Soft Tacos                             8.99
# Veggie Bowl                                  8.49
# Veggie Burrito                               8.49
# Veggie Crispy Tacos                          8.49
# Veggie Salad                                 8.49
# Veggie Salad Bowl                            8.75
# Veggie Soft Tacos                            8.49
